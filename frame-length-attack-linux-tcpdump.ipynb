# %%
# !tshark -n -r attack_linux_tcpdump.pcap -T fields -Eheader=y -e frame.number -e frame.len > frame.len

# %%
# !head -10 frame.len
# Out:
# frame.number	frame.len
# 1	60
# 2	60
# 3	60
# 4	60
# 5	83
# 6	134
# 7	60
# 8	60
# 9	60

# %%
import pandas as pd

# %%
df=pd.read_table("frame.len")

# %%
df
# Out:
#          frame.number  frame.len
# 0                   1         60
# 1                   2         60
# 2                   3         60
# 3                   4         60
# 4                   5         83
# 5                   6        134
# 6                   7         60
# 7                   8         60
# 8                   9         60
# 9                  10         60
# 10                 11         60
# 11                 12         60
# 12                 13         60
# 13                 14         60
# 14                 15         60
# 15                 16         60
# 16                 17         60
# 17                 18         60
# 18                 19         60
# 19                 20         60
# 20                 21         60
# 21                 22         60
# 22                 23         60
# 23                 24         60
# 24                 25         60
# 25                 26         60
# 26                 27         60
# ...

# %%
df["frame.len"].describe()
# Out:
# count    2331773.000000
# mean         419.504568
# std          586.083730
# min           42.000000
# 25%           62.000000
# 50%           74.000000
# 75%          610.000000
# max         1514.000000
# dtype: float64

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
figsize(10,6)
